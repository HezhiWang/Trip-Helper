# %%
import pandas as pd
import os
path = os.getcwd() + '/yelp_data.csv'
data_restaurant = pd.read_csv(path, encoding = 'latin1')

# %%
data_restaurant
# Out:
#                                                 address  \
# 0                    182 Havemeyer StBrooklyn, NY 11211
# 1                        219 W 116 StNew York, NY 10026
# 2                       165 W 26th StNew York, NY 10001
# 3     2065 Adam Clayton Powell Jr BlvdNew York, NY 1...
# 4                      210 W 118th StNew York, NY 10026
# 5                         218 3rd AveNew York, NY 10003
# 6                      163B W 29th StNew York, NY 10001
# 7                        42 E 20th StNew York, NY 10003
# 8                         207 2nd AveNew York, NY 10003
# 9                        43 E 19th StNew York, NY 10003
# 10                       134 Reade StNew York, NY 10013
# 11                      54 Carmine StNew York, NY 10014
# 12                      135 W 42nd StNew York, NY 10036
# 13                       653 11th AveNew York, NY 10036
# 14                       227 10th AveNew York, NY 10011
# 15                      72 Hudson AveBrooklyn, NY 11201
# ...
